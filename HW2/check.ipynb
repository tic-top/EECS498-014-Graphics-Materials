# %%
# 128
from PIL import Image
import matplotlib.pyplot as plt

# 加载 PPM 图片
image = Image.open("binary.ppm")

# 显示图片
plt.imshow(image)
plt.axis('off')  # 关闭坐标轴
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

# 加载 32 PPM 图片
image = Image.open("1.ppm")

# 显示图片
plt.imshow(image)
plt.axis('off')  # 关闭坐标轴
plt.show()
